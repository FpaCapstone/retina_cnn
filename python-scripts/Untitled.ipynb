# %%
from plot_metrics import plot_from_evaluation_results
plot_from_evaluation_results('evaluation_results/evaluation_20251109_164846')
# Out:
# 📥 Loading evaluation results from: evaluation_results/evaluation_20251109_164846
# ✅ Loading metrics from: evaluation_results/evaluation_20251109_164846/detailed_metrics.txt
#
# 📊 Creating per-class metrics plot...
# 💾 Saved per-class metrics plot to: evaluation_results/evaluation_20251109_164846/per_class_metrics.png
# ⚠️  Confusion matrix not available in results.
#    Only per-class metrics plotted.
#
# ✅ All available plots saved to: evaluation_results/evaluation_20251109_164846
# {'per_class_metrics': 'evaluation_results/evaluation_20251109_164846/per_class_metrics.png'}
